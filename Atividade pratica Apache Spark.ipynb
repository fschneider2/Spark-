# %% [markdown]
# Semana 01 - Agora que você já conhece os principais comandos do Apache Spark, vamos resolver um problema que simula uma situação do dia a dia de um Engenheiro/Cientista de Dados:
#
# Digamos que seu chefe lhe peça para que faça um estudo sobre alguns voos comerciais e para isso ele lhe fornece o mesmo dataset que já utilizamos (airlines de 2008, lembra?). O que ele pede é o seguinte:

# %%
airlines = spark.read.format("csv")\
                .option("header", "true")\
                .option("inferSchema" , "true")\
                .load("/databricks-datasets/asa/airlines/2008.csv" )

# %%
# Para visualização dos dados do DataFrame
airlines.limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>Month</th><th>DayofMonth</th><th>DayOfWeek</th><th>DepTime</th><th>CRSDepTime</th><th>ArrTime</th><th>CRSArrTime</th><th>UniqueCarrier</th><th>FlightNum</th><th>TailNum</th><th>ActualElapsedTime</th><th>CRSElapsedTime</th><th>AirTime</th><th>ArrDelay</th><th>DepDelay</th><th>Origin</th><th>Dest</th><th>Distance</th><th>TaxiIn</th><th>TaxiOut</th><th>Cancelled</th><th>CancellationCode</th><th>Diverted</th><th>CarrierDelay</th><th>WeatherDelay</th><th>NASDelay</th><th>SecurityDelay</th><th>LateAircraftDelay</th></tr></thead><tbody><tr><td>2008</td><td>1</td><td>3</td><td>4</td><td>2003</td><td>1955</td><td>2211</td><td>2225</td><td>WN</td><td>335</td><td>N712SW</td><td>128</td><td>150</td><td>116</td><td>-14</td><td>8</td><td>IAD</td><td>TPA</td><td>810</td><td>4</td><td>8</td><td>0</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>2008</td><td>1</td><td>3</td><td>4</td><td>754</td><td>735</td><td>1002</td><td>1000</td><td>WN</td><td>3231</td><td>N772SW</td><td>128</td><td>145</td><td>113</td><td>2</td><td>19</td><td>IAD</td><td>TPA</td><td>810</td><td>5</td><td>10</td><td>0</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>2008</td><td>1</td><td>3</td><td>4</td><td>628</td><td>620</td><td>804</td><td>750</td><td>WN</td><td>448</td><td>N428WN</td><td>96</td><td>90</td><td>76</td><td>14</td><td>8</td><td>IND</td><td>BWI</td><td>515</td><td>3</td><td>17</td><td>0</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>2008</td><td>1</td><td>3</td><td>4</td><td>926</td><td>930</td><td>1054</td><td>1100</td><td>WN</td><td>1746</td><td>N612SW</td><td>88</td><td>90</td><td>78</td><td>-6</td><td>-4</td><td>IND</td><td>BWI</td><td>515</td><td>3</td><td>7</td><td>0</td><td>null</td><td>0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>2008</td><td>1</td><td>3</td><td>4</td><td>1829</td><td>1755</td><td>1959</td><td>1925</td><td>WN</td><td>3920</td><td>N464WN</td><td>90</td><td>90</td><td>77</td><td>34</td><td>34</td><td>IND</td><td>BWI</td><td>515</td><td>3</td><td>10</td><td>0</td><td>null</td><td>0</td><td>2</td><td>0</td><td>0</td><td>0</td><td>32</td></tr></tbody></table></div>

# %% [markdown]
# 1) Uma tabela com a média de tempo de voo (ActualElapsedTime) e a média de atraso no embarque (DepDelay) separados por meses (Month).

# %%
from pyspark.sql.functions import avg

df = airlines.select('Month', 'ActualElapsedTime', 'DepDelay')

mean_per_month = df.groupBy('Month') \
                   .agg(avg('ActualElapsedTime').alias('avg_ActualElapsedTime'), \
                       avg('DepDelay').alias('avg_DepDelay'))

display(mean_per_month)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Month</th><th>avg_ActualElapsedTime</th><th>avg_DepDelay</th></tr></thead><tbody><tr><td>1</td><td>128.29696319384124</td><td>11.47609595943289</td></tr><tr><td>2</td><td>129.44371714586094</td><td>13.706226305045202</td></tr><tr><td>3</td><td>129.63611339983922</td><td>12.49126948010275</td></tr><tr><td>5</td><td>126.87376545785284</td><td>7.642741440912969</td></tr><tr><td>4</td><td>127.13476376416128</td><td>8.201132754082797</td></tr><tr><td>6</td><td>128.9144641603606</td><td>13.609818079614008</td></tr><tr><td>8</td><td>127.036379525593</td><td>9.61475257451315</td></tr><tr><td>7</td><td>128.03412449648454</td><td>11.807544712497146</td></tr><tr><td>9</td><td>123.22679133130671</td><td>3.961818849518357</td></tr><tr><td>10</td><td>123.35473154721042</td><td>3.803487686795168</td></tr><tr><td>11</td><td>125.59821264814961</td><td>5.420469498039744</td></tr><tr><td>12</td><td>129.8062952241747</td><td>17.30437978049954</td></tr></tbody></table></div>

# %% [markdown]
# 2) O número de voos que saem de Indianápolis e Las Vegas.

# %%
from pyspark.sql.functions import count

origins= ['IND','LAS']

amount_voo = airlines.select('Origin') \
             .filter(airlines.Origin.isin(origins)) \
             .groupBy('Origin') \
             .count()

# %%
amount_voo.show(truncate=False)
# Out:
# +------+------+
# |Origin|count |
# +------+------+
# |LAS   |172876|
# |IND   |42750 |
# +------+------+

# %%
# Só para testar as diferentes formas de visualização 
display(amount_voo)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Origin</th><th>count</th></tr></thead><tbody><tr><td>LAS</td><td>172876</td></tr><tr><td>IND</td><td>42750</td></tr></tbody></table></div>

# %% [markdown]
# 3) O número de voos que saem de Indianápolis e chegam em Las Vegas

# %%
amount_voo_IND_LAS = airlines.select('Origin', 'Dest') \
                             .filter("Origin == 'IND' AND Dest == 'LAS'" ) \
                             .count()

# %%
display(f"Sairam {amount_voo_IND_LAS} voos de Indianápolis com destino à Las Vegas")
# Out:
# 'Sairam 1675 voos de Indianápolis com destino à Las Vegas'
